# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None
from datetime import datetime, timedelta
import requests
from urllib.request import urlopen
from io import BytesIO
from zipfile import ZipFile
from pandas.io.json import json_normalize

# %%
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 100)

# %%
cutoff_date = pd.to_datetime('2017-03-12')
time_interval = 365
start_date = cutoff_date - timedelta(days=time_interval)
years = [2016, 2017]

# %%
counter = 0
df = []

for year in years:
    url = 'https://nvd.nist.gov/feeds/json/cve/1.0/nvdcve-1.0-'+str(year)+'.json.zip'
    extract_target = 'nvdcve-1.0-'+str(year)+'.json'
    z = urlopen(url)
    stage_1 = z.read()
    stage_2 = (BytesIO(stage_1))
    stage_3 = ZipFile(stage_2)
    stage_4 = stage_3.extract(extract_target)
    yearly_data = pd.read_json(stage_4)
    if counter == 0:
        df = yearly_data
    else:
        df = df.append(yearly_data)
    counter +=1
    print(year)
    print('complete')
# Out:
# 2016
# complete
# 2017
# complete

# %%
CVE_Items = json_normalize(df["CVE_Items"])

# %%
df = pd.concat([df.reset_index(), CVE_Items], axis=1)
df = df.drop(["index", "CVE_Items"], axis=1)

# %%
len(df["cve.CVE_data_meta.ID"].unique())
# Out:
# 25549

# %%
df = df.rename(columns={"cve.CVE_data_meta.ID": "CVE ID"})
CVE_ID = df["CVE ID"]
df.drop(labels=["CVE ID"], axis=1,inplace = True)
df.insert(0, "CVE ID", CVE_ID)

# %%
len(df[df.isnull().any(axis=1)])
# Out:
# 21321

# %%
len(df[df["impact.baseMetricV2.acInsufInfo"].isnull()])
# Out:
# 21208

# %%
df = df.drop(["impact.baseMetricV2.acInsufInfo"], axis=1)

# %%
len(df[df.isnull().any(axis=1)])
# Out:
# 3674

# %%
df[df.isnull().any(axis=1)].head()
# Out:
#            CVE ID CVE_data_type CVE_data_format  CVE_data_version  \
# 0   CVE-2016-0001           CVE           MITRE                 4
# 3   CVE-2016-0004           CVE           MITRE                 4
# 12  CVE-2016-0013           CVE           MITRE                 4
# 16  CVE-2016-0017           CVE           MITRE                 4
# 18  CVE-2016-0019           CVE           MITRE                 4
#
#     CVE_data_numberOfCVEs CVE_data_timestamp configurations.CVE_data_version  \
# 0                    9927  2019-07-19T07:54Z                             4.0
# 3                    9927  2019-07-19T07:54Z                             4.0
# 12                   9927  2019-07-19T07:54Z                             4.0
# 16                   9927  2019-07-19T07:54Z                             4.0
# 18                   9927  2019-07-19T07:54Z                             4.0
#
#                                  configurations.nodes  \
# 0                                                  []
# 3                                                  []
# 12                                                 []
# 16                                                 []
# 18  [{'operator': 'OR', 'cpe_match': [{'vulnerable...
#
#    cve.CVE_data_meta.ASSIGNER  \
# 0               cve@mitre.org
# 3               cve@mitre.org
# 12              cve@mitre.org
# 16              cve@mitre.org
# 18              cve@mitre.org
#
#                        cve.affects.vendor.vendor_data cve.data_format  \
# 0                                                  []           MITRE
# 3                                                  []           MITRE
# 12                                                 []           MITRE
# 16                                                 []           MITRE
# 18  [{'vendor_name': 'microsoft', 'product': {'pro...           MITRE
#
#    cve.data_type cve.data_version  \
# 0            CVE              4.0
# 3            CVE              4.0
# 12           CVE              4.0
# 16           CVE              4.0
# 18           CVE              4.0
#
#                      cve.description.description_data  \
# 0   [{'lang': 'en', 'value': '** REJECT **  DO NOT...
# 3   [{'lang': 'en', 'value': '** REJECT **  DO NOT...
# 12  [{'lang': 'en', 'value': '** REJECT **  DO NOT...
# 16  [{'lang': 'en', 'value': '** REJECT **  DO NOT...
# 18  [{'lang': 'en', 'value': 'The Remote Desktop P...
#
#                      cve.problemtype.problemtype_data  \
# 0                               [{'description': []}]
# 3                               [{'description': []}]
# 12                              [{'description': []}]
# 16                              [{'description': []}]
# 18  [{'description': [{'lang': 'en', 'value': 'CWE...
#
#                         cve.references.reference_data  \
# 0                                                  []
# 3                                                  []
# 12                                                 []
# 16                                                 []
# 18  [{'url': 'http://www.securitytracker.com/id/10...
#
#    impact.baseMetricV2.cvssV2.accessComplexity  \
# 0                                          NaN
# 3                                          NaN
# 12                                         NaN
# 16                                         NaN
# 18                                      MEDIUM
#
#    impact.baseMetricV2.cvssV2.accessVector  \
# 0                                      NaN
# 3                                      NaN
# 12                                     NaN
# 16                                     NaN
# 18                                 NETWORK
#
#    impact.baseMetricV2.cvssV2.authentication  \
# 0                                        NaN
# 3                                        NaN
# 12                                       NaN
# 16                                       NaN
# 18                                      NONE
#
#    impact.baseMetricV2.cvssV2.availabilityImpact  \
# 0                                            NaN
# 3                                            NaN
# 12                                           NaN
# 16                                           NaN
# 18                                      COMPLETE
#
#     impact.baseMetricV2.cvssV2.baseScore  \
# 0                                    NaN
# 3                                    NaN
# 12                                   NaN
# 16                                   NaN
# 18                                   9.3
#
#    impact.baseMetricV2.cvssV2.confidentialityImpact  \
# 0                                               NaN
# 3                                               NaN
# 12                                              NaN
# 16                                              NaN
# 18                                         COMPLETE
#
#    impact.baseMetricV2.cvssV2.integrityImpact  \
# 0                                         NaN
# 3                                         NaN
# 12                                        NaN
# 16                                        NaN
# 18                                   COMPLETE
#
#    impact.baseMetricV2.cvssV2.vectorString impact.baseMetricV2.cvssV2.version  \
# 0                                      NaN                                NaN
# 3                                      NaN                                NaN
# 12                                     NaN                                NaN
# 16                                     NaN                                NaN
# 18              AV:N/AC:M/Au:N/C:C/I:C/A:C                                2.0
#
#     impact.baseMetricV2.exploitabilityScore  impact.baseMetricV2.impactScore  \
# 0                                       NaN                              NaN
# 3                                       NaN                              NaN
# 12                                      NaN                              NaN
# 16                                      NaN                              NaN
# 18                                      8.6                             10.0
#
#    impact.baseMetricV2.obtainAllPrivilege  \
# 0                                     NaN
# 3                                     NaN
# 12                                    NaN
# 16                                    NaN
# 18                                  False
#
#    impact.baseMetricV2.obtainOtherPrivilege  \
# 0                                       NaN
# 3                                       NaN
# 12                                      NaN
# 16                                      NaN
# 18                                    False
#
#    impact.baseMetricV2.obtainUserPrivilege impact.baseMetricV2.severity  \
# 0                                      NaN                          NaN
# 3                                      NaN                          NaN
# 12                                     NaN                          NaN
# 16                                     NaN                          NaN
# 18                                   False                         HIGH
#
#    impact.baseMetricV2.userInteractionRequired  \
# 0                                          NaN
# 3                                          NaN
# 12                                         NaN
# 16                                         NaN
# 18                                         NaN
#
#    impact.baseMetricV3.cvssV3.attackComplexity  \
# 0                                          NaN
# 3                                          NaN
# 12                                         NaN
# 16                                         NaN
# 18                                        HIGH
#
#    impact.baseMetricV3.cvssV3.attackVector  \
# 0                                      NaN
# 3                                      NaN
# 12                                     NaN
# 16                                     NaN
# 18                                 NETWORK
#
#    impact.baseMetricV3.cvssV3.availabilityImpact  \
# 0                                            NaN
# 3                                            NaN
# 12                                           NaN
# 16                                           NaN
# 18                                          HIGH
#
#     impact.baseMetricV3.cvssV3.baseScore  \
# 0                                    NaN
# 3                                    NaN
# 12                                   NaN
# 16                                   NaN
# 18                                   8.1
#
#    impact.baseMetricV3.cvssV3.baseSeverity  \
# 0                                      NaN
# 3                                      NaN
# 12                                     NaN
# 16                                     NaN
# 18                                    HIGH
#
#    impact.baseMetricV3.cvssV3.confidentialityImpact  \
# 0                                               NaN
# 3                                               NaN
# 12                                              NaN
# 16                                              NaN
# 18                                             HIGH
#
#    impact.baseMetricV3.cvssV3.integrityImpact  \
# 0                                         NaN
# 3                                         NaN
# 12                                        NaN
# 16                                        NaN
# 18                                       HIGH
#
#    impact.baseMetricV3.cvssV3.privilegesRequired  \
# 0                                            NaN
# 3                                            NaN
# 12                                           NaN
# 16                                           NaN
# 18                                          NONE
#
#    impact.baseMetricV3.cvssV3.scope  \
# 0                               NaN
# 3                               NaN
# 12                              NaN
# 16                              NaN
# 18                        UNCHANGED
#
#    impact.baseMetricV3.cvssV3.userInteraction  \
# 0                                         NaN
# 3                                         NaN
# 12                                        NaN
# 16                                        NaN
# 18                                       NONE
#
#          impact.baseMetricV3.cvssV3.vectorString  \
# 0                                            NaN
# 3                                            NaN
# 12                                           NaN
# 16                                           NaN
# 18  CVSS:3.0/AV:N/AC:H/PR:N/UI:N/S:U/C:H/I:H/A:H
#
#    impact.baseMetricV3.cvssV3.version  \
# 0                                 NaN
# 3                                 NaN
# 12                                NaN
# 16                                NaN
# 18                                3.0
#
#     impact.baseMetricV3.exploitabilityScore  impact.baseMetricV3.impactScore  \
# 0                                       NaN                              NaN
# 3                                       NaN                              NaN
# 12                                      NaN                              NaN
# 16                                      NaN                              NaN
# 18                                      2.2                              5.9
#
#      lastModifiedDate      publishedDate
# 0   2017-05-11T14:29Z  2017-05-11T14:29Z
# 3   2017-05-11T14:29Z  2017-05-11T14:29Z
# 12  2017-05-11T14:29Z  2017-05-11T14:29Z
# 16  2017-05-11T14:29Z  2017-05-11T14:29Z
# 18  2018-10-30T16:27Z  2016-01-13T05:59Z

# %%
df[df.isnull().any(axis=1)].iloc[0]["cve.description.description_data"]
# Out:
# [{'lang': 'en',
#   'value': '** REJECT **  DO NOT USE THIS CANDIDATE NUMBER. ConsultIDs: none. Reason: The CNA or individual who requested this candidate did not associate it with any vulnerability during 2016. Notes: none.'}]

# %%
y = 0
for x in df["cve.description.description_data"]:
    if "REJECT" in (json_normalize(x)["value"])[0]:
        y+=1
    else:
        y
print(y)
# Out:
# 2955

# %%
df = df.dropna(axis=0)

# %%
df["publishedDate"] = pd.to_datetime(df["publishedDate"])

# %%
df = df[(df["publishedDate"] < cutoff_date) & (df["publishedDate"] > start_date)]

# %%
df["cve.problemtype.problemtype_data"].head(1).values[0]
# Out:
# [{'description': [{'lang': 'en', 'value': 'CWE-20'}]}]

# %%
CWE_entry_1 = []
CWE_index = df["cve.problemtype.problemtype_data"].index
for x in df["cve.problemtype.problemtype_data"]:
    CWE_normalized_json_step_1 = json_normalize(x)
    CWE_normalized_json_step_2 = CWE_normalized_json_step_1["description"][0]
    raw_CWE_entry = json_normalize(CWE_normalized_json_step_2)["value"][0]
    clean_CWE_entry = str(raw_CWE_entry)
    CWE_entry_1.append(clean_CWE_entry)
    
CWE_entry_1 = pd.Series(CWE_entry_1, index = CWE_index)

# %%
CWE_entry_2 = []

for x in df["cve.problemtype.problemtype_data"]:
    try:
        CWE_normalized_json_step_1 = json_normalize(x)
        CWE_normalized_json_step_2 = CWE_normalized_json_step_1["description"][0]
        raw_CWE_entry = json_normalize(CWE_normalized_json_step_2)["value"][1]
        clean_CWE_entry = str(raw_CWE_entry)
        CWE_entry_2.append(clean_CWE_entry)
    
    except:
        CWE_entry_2.append("NONE")

CWE_entry_2 = pd.Series(CWE_entry_2, index = CWE_index)

# %%
df_CWE = pd.concat([CWE_entry_1, CWE_entry_2], axis=1)
df_CWE.columns = ["CWE Code 1", "CWE Code 2"]

# %%
CWE_entry_1.unique()
# Out:
# array(['CWE-20', 'CWE-119', 'CWE-200', 'CWE-254', 'CWE-264', 'CWE-19',
#        'CWE-284', 'NVD-CWE-Other', 'CWE-601', 'CWE-79', 'CWE-89',
#        'CWE-77', 'CWE-399', 'CWE-611', 'CWE-532', 'NVD-CWE-noinfo',
#        'CWE-78', 'CWE-255', 'CWE-502', 'CWE-352', 'CWE-275', 'CWE-693',
#        'CWE-189', 'CWE-287', 'CWE-310', 'CWE-285', 'CWE-327', 'CWE-362',
#        'CWE-94', 'CWE-295', 'CWE-22', 'CWE-426', 'CWE-320', 'CWE-476',
#        'CWE-125', 'CWE-388', 'CWE-17', 'CWE-416', 'CWE-326', 'CWE-798',
#        'CWE-74', 'CWE-190', 'CWE-338', 'CWE-384', 'CWE-59', 'CWE-297',
#        'CWE-361', 'CWE-400', 'CWE-191', 'CWE-306', 'CWE-787', 'CWE-345',
#        'CWE-640', 'CWE-116', 'CWE-434', 'CWE-91', 'CWE-358', 'CWE-415',
#        'CWE-369', 'CWE-172', 'CWE-918', 'CWE-427', 'CWE-704', 'CWE-113',
#        'CWE-669', 'CWE-330', 'CWE-93', 'CWE-199', 'CWE-428', 'CWE-184',
#        'CWE-18', 'CWE-682', 'CWE-346', 'CWE-129', 'CWE-775', 'CWE-332',
#        'CWE-90', 'CWE-417', 'CWE-485', 'CWE-99', 'CWE-134', 'CWE-118',
#        'CWE-613'], dtype=object)

# %%
CWE_entry_2.unique()
# Out:
# array(['NONE', 'CWE-284', 'CWE-254', 'CWE-200', 'CWE-310', 'CWE-89',
#        'CWE-77', 'CWE-287', 'CWE-190', 'CWE-326', 'CWE-416', 'CWE-362',
#        'CWE-22', 'CWE-264', 'CWE-399', 'NVD-CWE-Other', 'CWE-787',
#        'CWE-20', 'CWE-189', 'CWE-255', 'CWE-79', 'CWE-78', 'CWE-345',
#        'CWE-798', 'CWE-611', 'CWE-476', 'CWE-93', 'CWE-125', 'CWE-285',
#        'NVD-CWE-noinfo', 'CWE-74', 'CWE-320', 'CWE-749', 'CWE-59',
#        'CWE-191', 'CWE-94', 'CWE-388', 'CWE-415', 'CWE-502', 'CWE-346'],
#       dtype=object)

# %%
def consolidate_unknowns(x):
    if x == "NVD-CWE-Other" or x == "NVD-CWE-noinfo":
        return "UNKNOWN"
    else:
        return x

# %%
df_CWE = df_CWE.applymap(consolidate_unknowns)
CWE_entry_1 = CWE_entry_1.apply(consolidate_unknowns)
CWE_entry_2 = CWE_entry_2.apply(consolidate_unknowns)

# %%
df_w_CWE_codes = df.join(df_CWE)

# %%
df_w_CWE_codes.head()
# Out:
#            CVE ID CVE_data_type CVE_data_format  CVE_data_version  \
# 24  CVE-2016-0025           CVE           MITRE                 4
# 25  CVE-2016-0026           CVE           MITRE                 4
# 27  CVE-2016-0028           CVE           MITRE                 4
# 69  CVE-2016-0070           CVE           MITRE                 4
# 72  CVE-2016-0073           CVE           MITRE                 4
#
#     CVE_data_numberOfCVEs CVE_data_timestamp configurations.CVE_data_version  \
# 24                   9927  2019-07-19T07:54Z                             4.0
# 25                   9927  2019-07-19T07:54Z                             4.0
# 27                   9927  2019-07-19T07:54Z                             4.0
# 69                   9927  2019-07-19T07:54Z                             4.0
# 72                   9927  2019-07-19T07:54Z                             4.0
#
#                                  configurations.nodes  \
# 24  [{'operator': 'OR', 'cpe_match': [{'vulnerable...
# 25  [{'operator': 'OR', 'cpe_match': [{'vulnerable...
# 27  [{'operator': 'AND', 'children': [{'operator':...
# 69  [{'operator': 'OR', 'cpe_match': [{'vulnerable...
# 72  [{'operator': 'OR', 'cpe_match': [{'vulnerable...
#
#    cve.CVE_data_meta.ASSIGNER  \
# 24              cve@mitre.org
# 25              cve@mitre.org
# 27              cve@mitre.org
# 69              cve@mitre.org
# 72              cve@mitre.org
#
#                        cve.affects.vendor.vendor_data cve.data_format  \
# 24  [{'vendor_name': 'microsoft', 'product': {'pro...           MITRE
# 25  [{'vendor_name': 'microsoft', 'product': {'pro...           MITRE
# 27  [{'vendor_name': 'microsoft', 'product': {'pro...           MITRE
# 69  [{'vendor_name': 'microsoft', 'product': {'pro...           MITRE
# 72  [{'vendor_name': 'microsoft', 'product': {'pro...           MITRE
#
#    cve.data_type cve.data_version  \
# 24           CVE              4.0
# 25           CVE              4.0
# 27           CVE              4.0
# 69           CVE              4.0
# 72           CVE              4.0
#
#                      cve.description.description_data  \
# 24  [{'lang': 'en', 'value': 'Microsoft Word 2007 ...
# 25  [{'lang': 'en', 'value': 'The Common Log File ...
# 27  [{'lang': 'en', 'value': 'Outlook Web Access (...
# 69  [{'lang': 'en', 'value': 'The kernel in Micros...
# 72  [{'lang': 'en', 'value': 'The kernel in Micros...
#
#                      cve.problemtype.problemtype_data  \
# 24  [{'description': [{'lang': 'en', 'value': 'CWE...
# 25  [{'description': [{'lang': 'en', 'value': 'CWE...
# 27  [{'description': [{'lang': 'en', 'value': 'CWE...
# 69  [{'description': [{'lang': 'en', 'value': 'CWE...
# 72  [{'description': [{'lang': 'en', 'value': 'CWE...
#
#                         cve.references.reference_data  \
# 24  [{'url': 'http://www.securitytracker.com/id/10...
# 25  [{'url': 'http://www.securityfocus.com/bid/939...
# 27  [{'url': 'http://www.securitytracker.com/id/10...
# 69  [{'url': 'http://www.securityfocus.com/bid/933...
# 72  [{'url': 'http://www.securityfocus.com/bid/933...
#
#    impact.baseMetricV2.cvssV2.accessComplexity  \
# 24                                      MEDIUM
# 25                                      MEDIUM
# 27                                      MEDIUM
# 69                                      MEDIUM
# 72                                         LOW
#
#    impact.baseMetricV2.cvssV2.accessVector  \
# 24                                 NETWORK
# 25                                 NETWORK
# 27                                 NETWORK
# 69                                 NETWORK
# 72                                   LOCAL
#
#    impact.baseMetricV2.cvssV2.authentication  \
# 24                                      NONE
# 25                                      NONE
# 27                                      NONE
# 69                                      NONE
# 72                                      NONE
#
#    impact.baseMetricV2.cvssV2.availabilityImpact  \
# 24                                      COMPLETE
# 25                                      COMPLETE
# 27                                          NONE
# 69                                          NONE
# 72                                          NONE
#
#     impact.baseMetricV2.cvssV2.baseScore  \
# 24                                   9.3
# 25                                   9.3
# 27                                   4.3
# 69                                   4.3
# 72                                   2.1
#
#    impact.baseMetricV2.cvssV2.confidentialityImpact  \
# 24                                         COMPLETE
# 25                                         COMPLETE
# 27                                          PARTIAL
# 69                                          PARTIAL
# 72                                          PARTIAL
#
#    impact.baseMetricV2.cvssV2.integrityImpact  \
# 24                                   COMPLETE
# 25                                   COMPLETE
# 27                                       NONE
# 69                                       NONE
# 72                                       NONE
#
#    impact.baseMetricV2.cvssV2.vectorString impact.baseMetricV2.cvssV2.version  \
# 24              AV:N/AC:M/Au:N/C:C/I:C/A:C                                2.0
# 25              AV:N/AC:M/Au:N/C:C/I:C/A:C                                2.0
# 27              AV:N/AC:M/Au:N/C:P/I:N/A:N                                2.0
# 69              AV:N/AC:M/Au:N/C:P/I:N/A:N                                2.0
# 72              AV:L/AC:L/Au:N/C:P/I:N/A:N                                2.0
#
#     impact.baseMetricV2.exploitabilityScore  impact.baseMetricV2.impactScore  \
# 24                                      8.6                             10.0
# 25                                      8.6                             10.0
# 27                                      8.6                              2.9
# 69                                      8.6                              2.9
# 72                                      3.9                              2.9
#
#    impact.baseMetricV2.obtainAllPrivilege  \
# 24                                  False
# 25                                  False
# 27                                  False
# 69                                  False
# 72                                  False
#
#    impact.baseMetricV2.obtainOtherPrivilege  \
# 24                                    False
# 25                                    False
# 27                                    False
# 69                                    False
# 72                                    False
#
#    impact.baseMetricV2.obtainUserPrivilege impact.baseMetricV2.severity  \
# 24                                   False                         HIGH
# 25                                   False                         HIGH
# 27                                   False                       MEDIUM
# 69                                   False                       MEDIUM
# 72                                   False                          LOW
#
#    impact.baseMetricV2.userInteractionRequired  \
# 24                                        True
# 25                                        True
# 27                                        True
# 69                                        True
# 72                                       False
#
#    impact.baseMetricV3.cvssV3.attackComplexity  \
# 24                                         LOW
# 25                                         LOW
# 27                                         LOW
# 69                                         LOW
# 72                                         LOW
#
#    impact.baseMetricV3.cvssV3.attackVector  \
# 24                                   LOCAL
# 25                                   LOCAL
# 27                                   LOCAL
# 69                                   LOCAL
# 72                                   LOCAL
#
#    impact.baseMetricV3.cvssV3.availabilityImpact  \
# 24                                          HIGH
# 25                                          HIGH
# 27                                          NONE
# 69                                          NONE
# 72                                          NONE
#
#     impact.baseMetricV3.cvssV3.baseScore  \
# 24                                   7.3
# 25                                   7.8
# 27                                   5.5
# 69                                   5.5
# 72                                   5.0
#
#    impact.baseMetricV3.cvssV3.baseSeverity  \
# 24                                    HIGH
# 25                                    HIGH
# 27                                  MEDIUM
# 69                                  MEDIUM
# 72                                  MEDIUM
#
#    impact.baseMetricV3.cvssV3.confidentialityImpact  \
# 24                                             HIGH
# 25                                             HIGH
# 27                                             HIGH
# 69                                             HIGH
# 72                                             HIGH
#
#    impact.baseMetricV3.cvssV3.integrityImpact  \
# 24                                       HIGH
# 25                                       HIGH
# 27                                       NONE
# 69                                       NONE
# 72                                       NONE
#
#    impact.baseMetricV3.cvssV3.privilegesRequired  \
# 24                                           LOW
# 25                                          NONE
# 27                                          NONE
# 69                                          NONE
# 72                                           LOW
#
#    impact.baseMetricV3.cvssV3.scope  \
# 24                        UNCHANGED
# 25                        UNCHANGED
# 27                        UNCHANGED
# 69                        UNCHANGED
# 72                        UNCHANGED
#
#    impact.baseMetricV3.cvssV3.userInteraction  \
# 24                                   REQUIRED
# 25                                   REQUIRED
# 27                                   REQUIRED
# 69                                   REQUIRED
# 72                                   REQUIRED
#
#          impact.baseMetricV3.cvssV3.vectorString  \
# 24  CVSS:3.0/AV:L/AC:L/PR:L/UI:R/S:U/C:H/I:H/A:H
# 25  CVSS:3.0/AV:L/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:H
# 27  CVSS:3.0/AV:L/AC:L/PR:N/UI:R/S:U/C:H/I:N/A:N
# 69  CVSS:3.0/AV:L/AC:L/PR:N/UI:R/S:U/C:H/I:N/A:N
# 72  CVSS:3.0/AV:L/AC:L/PR:L/UI:R/S:U/C:H/I:N/A:N
#
#    impact.baseMetricV3.cvssV3.version  \
# 24                                3.0
# 25                                3.0
# 27                                3.0
# 69                                3.0
# 72                                3.0
#
#     impact.baseMetricV3.exploitabilityScore  impact.baseMetricV3.impactScore  \
# 24                                      1.3                              5.9
# 25                                      1.8                              5.9
# 27                                      1.8                              3.6
# 69                                      1.8                              3.6
# 72                                      1.3                              3.6
#
#      lastModifiedDate       publishedDate CWE Code 1 CWE Code 2
# 24  2018-10-12T22:10Z 2016-06-16 01:59:00     CWE-20       NONE
# 25  2018-10-12T22:10Z 2016-11-10 06:59:00    CWE-119       NONE
# 27  2018-10-12T22:10Z 2016-06-16 01:59:00    CWE-200       NONE
# 69  2018-10-12T22:10Z 2016-10-14 02:59:00    CWE-200       NONE
# 72  2018-10-12T22:10Z 2016-10-14 02:59:00    CWE-200       NONE

# %%
from bs4 import BeautifulSoup
import lxml.etree

# %%
NVD_CWE_description_url = requests.get("https://nvd.nist.gov/vuln/categories")
CWE_definitions_page_soup =  BeautifulSoup(NVD_CWE_description_url.content, "html5lib")
table = CWE_definitions_page_soup.find_all('table')[0] 
df_CWE_definitions = pd.read_html(str(table))[0]

# %%
df_CWE_definitions
# Out:
#         Name                                             CWE-ID  \
# 0    CWE-824                    Access of Uninitialized Pointer
# 1    CWE-407                             Algorithmic Complexity
# 2    CWE-774  Allocation of File Descriptors or Handles With...
# 3     CWE-88                 Argument Injection or Modification
# 4    CWE-405    Asymmetric Resource Consumption (Amplification)
# 5    CWE-287                              Authentication Issues
# 6    CWE-119                                      Buffer Errors
# 7    CWE-417                            Channel and Path Errors
# 8    CWE-171  Cleansing, Canonicalization, and Comparison Er...
# 9     CWE-17                                               Code
# ..       ...                                                ...
# 114  CWE-601  URL Redirection to Untrusted Site ('Open Redir...
# 115  CWE-416                                     Use After Free
# 116  CWE-327   Use of a Broken or Risky Cryptographic Algorithm
# 117  CWE-338  Use of Cryptographically Weak Pseudo-Random Nu...
# 118  CWE-798                      Use of Hard-coded Credentials
# 119  CWE-330                Use of Insufficiently Random Values
# 120  CWE-694  Use of Multiple Resources with Duplicate Ident...
# 121  CWE-640  Weak Password Recovery Mechanism for Forgotten...
# 122  CWE-123                         Write-what-where Condition
# 123   CWE-91          XML Injection (aka Blind XPath Injection)
#
#                                            Description
# 0    The program accesses or uses a pointer that ha...
# 1    An algorithm in a product has an inefficient w...
# 2    The software allocates file descriptors or han...
# 3    The software does not sufficiently delimit the...
# 4    Software that does not appropriately monitor o...
# 5    When an actor claims to have a given identity,...
# 6    The software performs operations on a memory b...
# 7    Weaknesses in this category are related to imp...
# 8    Weaknesses in this category are related to imp...
# 9    Weaknesses in this category are typically intr...
# ..                                                 ...
# 114  A web application accepts a user-controlled in...
# 115  Referencing memory after it has been freed can...
# 116  The use of a broken or risky cryptographic alg...
# 117  The product uses a Pseudo-Random Number Genera...
# 118  The software contains hard-coded credentials, ...
# 119  The software may use insufficiently random num...
# 120  The software uses multiple resources that can ...
# 121  The software contains a mechanism for users to...
# 122  Any condition where the attacker has the abili...
# 123  The software does not properly neutralize spec...
#
# [124 rows x 3 columns]

# %%
df_w_CWE_defs = df_w_CWE_codes.merge(df_CWE_definitions, how="left", left_on= "CWE Code 1", right_on = "Name")

# %%
df_w_CWE_defs = df_w_CWE_defs.rename(columns={'CWE-ID': 'CWE Code 1 Name', 'Description': 'CWE Code 1 Description'})
df_w_CWE_defs = df_w_CWE_defs.drop(["Name"], axis=1)

# %%
df_w_CWE_defs = df_w_CWE_defs.merge(df_CWE_definitions, how="left", left_on= "CWE Code 2", right_on = "Name")

# %%
df_w_CWE_defs = df_w_CWE_defs.rename(columns={'CWE-ID': 'CWE Code 2 Name', 'Description': 'CWE Code 2 Description'})
df_w_CWE_defs = df_w_CWE_defs.drop(["Name"], axis=1)

# %%
df_w_CWE_defs_cleaned = df_w_CWE_defs.drop(["CVE_data_type", "CVE_data_format", "cve.affects.vendor.vendor_data", "cve.problemtype.problemtype_data", "cve.description.description_data", "cve.references.reference_data", "CVE_data_version", "CVE_data_numberOfCVEs", "impact.baseMetricV2.cvssV2.vectorString", "impact.baseMetricV3.cvssV3.vectorString", "CVE_data_timestamp", "configurations.CVE_data_version", "configurations.nodes", "cve.CVE_data_meta.ASSIGNER", "cve.data_format", "cve.data_type", "cve.data_version", "lastModifiedDate", "publishedDate"], axis=1)

# %%
df_w_CWE_defs_cleaned.head()
# Out:
#           CVE ID impact.baseMetricV2.cvssV2.accessComplexity  \
# 0  CVE-2016-0025                                      MEDIUM
# 1  CVE-2016-0026                                      MEDIUM
# 2  CVE-2016-0028                                      MEDIUM
# 3  CVE-2016-0070                                      MEDIUM
# 4  CVE-2016-0073                                         LOW
#
#   impact.baseMetricV2.cvssV2.accessVector  \
# 0                                 NETWORK
# 1                                 NETWORK
# 2                                 NETWORK
# 3                                 NETWORK
# 4                                   LOCAL
#
#   impact.baseMetricV2.cvssV2.authentication  \
# 0                                      NONE
# 1                                      NONE
# 2                                      NONE
# 3                                      NONE
# 4                                      NONE
#
#   impact.baseMetricV2.cvssV2.availabilityImpact  \
# 0                                      COMPLETE
# 1                                      COMPLETE
# 2                                          NONE
# 3                                          NONE
# 4                                          NONE
#
#    impact.baseMetricV2.cvssV2.baseScore  \
# 0                                   9.3
# 1                                   9.3
# 2                                   4.3
# 3                                   4.3
# 4                                   2.1
#
#   impact.baseMetricV2.cvssV2.confidentialityImpact  \
# 0                                         COMPLETE
# 1                                         COMPLETE
# 2                                          PARTIAL
# 3                                          PARTIAL
# 4                                          PARTIAL
#
#   impact.baseMetricV2.cvssV2.integrityImpact  \
# 0                                   COMPLETE
# 1                                   COMPLETE
# 2                                       NONE
# 3                                       NONE
# 4                                       NONE
#
#   impact.baseMetricV2.cvssV2.version  impact.baseMetricV2.exploitabilityScore  \
# 0                                2.0                                      8.6
# 1                                2.0                                      8.6
# 2                                2.0                                      8.6
# 3                                2.0                                      8.6
# 4                                2.0                                      3.9
#
#    impact.baseMetricV2.impactScore impact.baseMetricV2.obtainAllPrivilege  \
# 0                             10.0                                  False
# 1                             10.0                                  False
# 2                              2.9                                  False
# 3                              2.9                                  False
# 4                              2.9                                  False
#
#   impact.baseMetricV2.obtainOtherPrivilege  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#   impact.baseMetricV2.obtainUserPrivilege impact.baseMetricV2.severity  \
# 0                                   False                         HIGH
# 1                                   False                         HIGH
# 2                                   False                       MEDIUM
# 3                                   False                       MEDIUM
# 4                                   False                          LOW
#
#   impact.baseMetricV2.userInteractionRequired  \
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                       False
#
#   impact.baseMetricV3.cvssV3.attackComplexity  \
# 0                                         LOW
# 1                                         LOW
# 2                                         LOW
# 3                                         LOW
# 4                                         LOW
#
#   impact.baseMetricV3.cvssV3.attackVector  \
# 0                                   LOCAL
# 1                                   LOCAL
# 2                                   LOCAL
# 3                                   LOCAL
# 4                                   LOCAL
#
#   impact.baseMetricV3.cvssV3.availabilityImpact  \
# 0                                          HIGH
# 1                                          HIGH
# 2                                          NONE
# 3                                          NONE
# 4                                          NONE
#
#    impact.baseMetricV3.cvssV3.baseScore  \
# 0                                   7.3
# 1                                   7.8
# 2                                   5.5
# 3                                   5.5
# 4                                   5.0
#
#   impact.baseMetricV3.cvssV3.baseSeverity  \
# 0                                    HIGH
# 1                                    HIGH
# 2                                  MEDIUM
# 3                                  MEDIUM
# 4                                  MEDIUM
#
#   impact.baseMetricV3.cvssV3.confidentialityImpact  \
# 0                                             HIGH
# 1                                             HIGH
# 2                                             HIGH
# 3                                             HIGH
# 4                                             HIGH
#
#   impact.baseMetricV3.cvssV3.integrityImpact  \
# 0                                       HIGH
# 1                                       HIGH
# 2                                       NONE
# 3                                       NONE
# 4                                       NONE
#
#   impact.baseMetricV3.cvssV3.privilegesRequired  \
# 0                                           LOW
# 1                                          NONE
# 2                                          NONE
# 3                                          NONE
# 4                                           LOW
#
#   impact.baseMetricV3.cvssV3.scope impact.baseMetricV3.cvssV3.userInteraction  \
# 0                        UNCHANGED                                   REQUIRED
# 1                        UNCHANGED                                   REQUIRED
# 2                        UNCHANGED                                   REQUIRED
# 3                        UNCHANGED                                   REQUIRED
# 4                        UNCHANGED                                   REQUIRED
#
#   impact.baseMetricV3.cvssV3.version  impact.baseMetricV3.exploitabilityScore  \
# 0                                3.0                                      1.3
# 1                                3.0                                      1.8
# 2                                3.0                                      1.8
# 3                                3.0                                      1.8
# 4                                3.0                                      1.3
#
#    impact.baseMetricV3.impactScore CWE Code 1 CWE Code 2  \
# 0                              5.9     CWE-20       NONE
# 1                              5.9    CWE-119       NONE
# 2                              3.6    CWE-200       NONE
# 3                              3.6    CWE-200       NONE
# 4                              3.6    CWE-200       NONE
#
#                  CWE Code 1 Name  \
# 0               Input Validation
# 1                  Buffer Errors
# 2  Information Leak / Disclosure
# 3  Information Leak / Disclosure
# 4  Information Leak / Disclosure
#
#                               CWE Code 1 Description CWE Code 2 Name  \
# 0  The product does not validate or incorrectly v...             NaN
# 1  The software performs operations on a memory b...             NaN
# 2  An information exposure is the intentional or ...             NaN
# 3  An information exposure is the intentional or ...             NaN
# 4  An information exposure is the intentional or ...             NaN
#
#   CWE Code 2 Description
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
# %matplotlib inline

# %%
CWE_counts_1 = CWE_entry_1.value_counts().sort_values(axis=0, ascending=False)
CWE_counts_1

# %%
CWE_counts_1.plot(kind = "bar", figsize = (20,8))
plt.title("Primary CWE Code by Incidence in 2017 NVD Data", fontsize = 24)
plt.show();

# %%
CWE_119_info = df_w_CWE_defs_cleaned[df_w_CWE_defs_cleaned["CWE Code 1"]=="CWE-119"][["CWE Code 1", "CWE Code 1 Name", "CWE Code 1 Description"]].iloc[0]
print(CWE_119_info[0])
print(CWE_119_info[1])
print(CWE_119_info[2])

# %%
CWE_counts_2 = CWE_entry_2.value_counts().sort_values(axis=0, ascending=False)
CWE_counts_2

# %%
CWE_counts_2.drop("NONE").plot(kind = "bar", figsize = (20,8))
plt.title("Secondary CWE Code by Incidence in 2017 NVD Data", fontsize = 24)
plt.ylim(top=60)
plt.show();

# %%
CWE_200_info = df_w_CWE_defs_cleaned[df_w_CWE_defs_cleaned["CWE Code 1"]=="CWE-200"][["CWE Code 1", "CWE Code 1 Name", "CWE Code 1 Description"]].iloc[0]
print(CWE_200_info[0])
print(CWE_200_info[1])
print(CWE_200_info[2])

# %%
df_w_CWE_defs_cleaned["impact.baseMetricV3.cvssV3.baseScore"].plot(kind = "hist", figsize = (20,8))
plt.title("Distribution of CVSS 3.0 Base Score in 2017 NVD Data", fontsize = 24)
plt.xlabel('CVSS 3.0 Base Score');

# %%
CWE_1_count = df_w_CWE_defs_cleaned.groupby(["CWE Code 1"]).count()["CVE ID"].sort_values(ascending=False)

# %%
CWE_1_base = df_w_CWE_defs_cleaned.groupby(["CWE Code 1"]).mean()["impact.baseMetricV3.cvssV3.baseScore"].sort_values(ascending=False)

# %%
CWE_1_summary = pd.concat([CWE_1_count, CWE_1_base], axis=1, sort=True)

# %%
CWE_1_summary = CWE_1_summary.rename(columns={'CVE ID': 'Count', 'impact.baseMetricV3.cvssV3.baseScore': 'CVSS 3.0 Score'})

# %%
CWE_1_summary = CWE_1_summary.sort_values(by=['Count'], ascending=False)

# %%
fig, ax1 = plt.subplots(figsize = (20,8))

ax2 = ax1.twinx()
ax1.bar(CWE_1_summary.index, CWE_1_summary["Count"])
ax2.plot(CWE_1_summary.index, CWE_1_summary["CVSS 3.0 Score"], 'red')

ax1.set_xlabel('Primary CWE Code')
ax1.set_ylabel('Count of incidents')
ax2.set_ylabel('Base CVSS 3.0 Score', color='red')
ax2.set_ylim(bottom = 5, top = 10)
    
for tick in ax1.get_xticklabels():
    tick.set_rotation(90)
    
plt.show()

# %%
CWE_2_count = df_w_CWE_defs_cleaned.groupby(["CWE Code 2"]).count()["CVE ID"].sort_values(ascending=False)

# %%
CWE_2_base_CVSS = df_w_CWE_defs_cleaned.groupby(["CWE Code 2"]).mean()["impact.baseMetricV3.cvssV3.baseScore"].sort_values(ascending=False)

# %%
CWE_2_summary = pd.concat([CWE_2_count, CWE_2_base_CVSS], axis=1, sort=True)

# %%
CWE_2_summary = CWE_2_summary.rename(columns={'CVE ID': 'Count', 'impact.baseMetricV3.cvssV3.baseScore': 'CVSS 3.0 Score'})

# %%
CWE_2_summary = CWE_2_summary.sort_values(by=['Count'], ascending=False)

# %%
fig, ax1 = plt.subplots(figsize = (20,8))

ax2 = ax1.twinx()
ax1.bar(CWE_2_summary.drop("NONE").index, CWE_2_summary.drop("NONE")["Count"], color ='green')
ax2.plot(CWE_2_summary.drop("NONE").index, CWE_2_summary.drop("NONE")["CVSS 3.0 Score"], color = 'black')

ax1.set_xlabel('Secondary CWE Code')
ax1.set_ylabel('Count of incidents')
ax2.set_ylabel('Base CVSS 3.0 Score')
ax2.set_ylim(bottom = 5, top = 10)
    
for tick in ax1.get_xticklabels():
    tick.set_rotation(90)
    
plt.show()

# %%
df_incident_counts = ((df_w_CWE_defs_cleaned.groupby("CWE Code 1").count())["CVE ID"]).to_frame()

# %%
df_incident_counts = df_incident_counts.rename(columns={"CVE ID": "CWE Count"})

# %%
df_w_CWE_defs_counts = df_w_CWE_defs_cleaned.merge(df_incident_counts, how="left", on="CWE Code 1")

# %%
df_sig_CWE = df_w_CWE_defs_counts[df_w_CWE_defs_counts["CWE Count"]>99]

# %%
df_sig_CWE.groupby("CWE Code 1").mean()["impact.baseMetricV3.cvssV3.baseScore"].sort_values(ascending=False)

# %%
CWE_416_info = df_w_CWE_defs_cleaned[df_w_CWE_defs_cleaned["CWE Code 1"]=="CWE-416"][["CWE Code 1", "CWE Code 1 Name", "CWE Code 1 Description"]].iloc[0]
print(CWE_416_info[0])
print(CWE_416_info[1])
print(CWE_416_info[2])

# %%
CWE_89_info = df_w_CWE_defs_cleaned[df_w_CWE_defs_cleaned["CWE Code 1"]=="CWE-89"][["CWE Code 1", "CWE Code 1 Name", "CWE Code 1 Description"]].iloc[0]
print(CWE_89_info[0])
print(CWE_89_info[1])
print(CWE_89_info[2])

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
def clustering_errors(k, data):
    kmeans = KMeans(n_clusters=k, random_state=42).fit(data)
    predictions = kmeans.predict(data)
    silhouette_avg = silhouette_score(data, predictions)
    return silhouette_avg

# %%
feature_analysis = df_w_CWE_defs_cleaned.drop(["CVE ID","CWE Code 1 Name",
                                               "CWE Code 2 Name",
                                               "CWE Code 1 Description",
                                               "CWE Code 2 Description",
                                               "impact.baseMetricV2.cvssV2.accessComplexity",
                                               "impact.baseMetricV2.cvssV2.accessVector",
                                               "impact.baseMetricV2.cvssV2.authentication",
                                               "impact.baseMetricV2.cvssV2.availabilityImpact",
                                               "impact.baseMetricV2.cvssV2.baseScore",
                                               "impact.baseMetricV2.cvssV2.confidentialityImpact",
                                               "impact.baseMetricV2.cvssV2.integrityImpact",
                                               "impact.baseMetricV2.cvssV2.version",
                                               "impact.baseMetricV2.exploitabilityScore",
                                               "impact.baseMetricV2.impactScore",
                                               "impact.baseMetricV2.obtainAllPrivilege",
                                               "impact.baseMetricV2.obtainOtherPrivilege",
                                               "impact.baseMetricV2.obtainUserPrivilege",
                                               "impact.baseMetricV2.severity",
                                               "impact.baseMetricV2.userInteractionRequired",
                                               "impact.baseMetricV3.cvssV3.version"], axis=1)

# %%
feature_analysis = pd.get_dummies(feature_analysis)

# %%
feature_analysis = feature_analysis.apply(pd.to_numeric, errors='coerce')

# %%
feature_analysis.head()

# %%
possible_k_values = range(2, 11, 1)

errors_per_k = [clustering_errors(k, feature_analysis) for k in possible_k_values]

# %%
list(zip(possible_k_values, errors_per_k))

# %%
fig, ax = plt.subplots(figsize=(20, 8))
ax.set_xlabel('K - number of clusters')
ax.set_ylabel('Silhouette Score (higher is better)')
ax.plot(possible_k_values, errors_per_k)
plt.title("Usefulness of Various Cluster Numbers in Analyzing 2017 NVD Data", fontsize = 24)

xticks = np.arange(min(possible_k_values), max(possible_k_values)+2, 1)
ax.set_xticks(xticks, minor=False)
ax.set_xticks(xticks, minor=True)
ax.xaxis.grid(True, which='both')
yticks = np.arange(round(min(errors_per_k), 2), max(errors_per_k), .05)
ax.set_yticks(yticks, minor=False)
ax.set_yticks(yticks, minor=True)
ax.yaxis.grid(True, which='both')

# %%
kmeans_6 = KMeans(n_clusters = 6, random_state = 42)
predictions_clusters = kmeans_6.fit_predict(feature_analysis)

# %%
np.unique(predictions_clusters, return_counts=True)

# %%
predictions_clusters

# %%
predictions_clusters = predictions_clusters + 1

# %%
df_predicted_clusters = pd.DataFrame(predictions_clusters)
df_predicted_clusters = df_predicted_clusters.rename(columns={0: "Cluster"})

# %%
df_predicted_clusters["Cluster"].value_counts().sort_index()

# %%
df_CWE_clusters = df_w_CWE_defs_cleaned.join(pd.DataFrame(df_predicted_clusters))

# %%
df_CWE_base_CVSS = df_CWE_clusters.groupby("Cluster").mean()["impact.baseMetricV3.cvssV3.baseScore"].sort_values(ascending=False)

# %%
fig = df_CWE_base_CVSS.plot(kind="bar", figsize = (16,6), color = "b")
fig.set_ylabel('CVSS 3.0 Score');

for tick in fig.get_xticklabels():
    tick.set_rotation(0)

# %%
colors_clusters = list(np.sort(df_CWE_clusters['Cluster'].unique()))
colors_clusters

# %%
plt.figure(figsize=(16, 16))
plt.xlabel('CVSS 3.0 Exploitability Score')
plt.ylabel('CVSS 3.0 Impact Score')
colors_clusters = list(np.sort(df_CWE_clusters['Cluster'].unique()))
for i in range(len(colors_clusters)):
    data = df_CWE_clusters.loc[df_CWE_clusters["Cluster"] == colors_clusters[i]]
    plt.scatter("impact.baseMetricV3.exploitabilityScore", "impact.baseMetricV3.impactScore", s = 500, data = data, label = colors_clusters[i])

leg = plt.legend(markerscale = 0.5, title = "Cluster", loc='upper right', bbox_to_anchor=(1.07, 1))

for lh in leg.legendHandles: 
    lh.set_alpha(1)
    
plt.show()

# %%
def rand_jitter(arr):
    stdev = .02*(max(arr)-min(arr))
    return arr + np.random.randn(len(arr)) * stdev

# %%
plt.figure(figsize=(16, 16))
plt.xlabel('CVSS 3.0 Exploitability Score')
plt.ylabel('CVSS 3.0 Impact Score')
colors_clusters = list(np.sort(df_CWE_clusters['Cluster'].unique()))
for i in range(len(colors_clusters)):
    data = df_CWE_clusters.loc[df_CWE_clusters["Cluster"] == colors_clusters[i]]
    data["impact.baseMetricV3.exploitabilityScore"] = rand_jitter(data["impact.baseMetricV3.exploitabilityScore"])
    data["impact.baseMetricV3.impactScore"] = rand_jitter(data["impact.baseMetricV3.impactScore"])
    plt.scatter("impact.baseMetricV3.exploitabilityScore", "impact.baseMetricV3.impactScore", s = 100, alpha = 0.1, cmap = "set1", data=data, label=colors_clusters[i])

leg = plt.legend(markerscale = 1, title = "Cluster", loc='upper right', bbox_to_anchor=(1.07, 1))

for lh in leg.legendHandles:
    lh.set_alpha(1)
    
plt.show()

# %%
CVE_Equifax = df_w_CWE_defs_cleaned[df_w_CWE_defs_cleaned["CVE ID"]=="CVE-2017-5638"]
CVE_Equifax

# %%
CWE_Equifax = df_w_CWE_defs_cleaned[df_w_CWE_defs_cleaned["CWE Code 1"]=="CWE-20"][["CWE Code 1", "CWE Code 1 Name", "CWE Code 1 Description"]].iloc[0]
print(CWE_Equifax[0])
print(CWE_Equifax[1])
print(CWE_Equifax[2])

# %%
df_CWE_clusters[df_CWE_clusters["CVE ID"]=="CVE-2017-5638"]["Cluster"]

# %%
plt.figure(figsize=(16, 16))

plt.xlabel('CVSS 3.0 Exploitability Score')
plt.ylabel('CVSS 3.0 Impact Score')

cluster_colors = list(np.sort(df_CWE_clusters['Cluster'].unique()))

for i in range(len(colors_clusters)):
    data = df_CWE_clusters.loc[df_CWE_clusters["Cluster"] == colors_clusters[i]]
    data["impact.baseMetricV3.exploitabilityScore"] = rand_jitter(data["impact.baseMetricV3.exploitabilityScore"])
    data["impact.baseMetricV3.impactScore"] = rand_jitter(data["impact.baseMetricV3.impactScore"])
    plt.scatter("impact.baseMetricV3.exploitabilityScore", "impact.baseMetricV3.impactScore", s = 100, alpha = 0.1, cmap = "tab30", data=data, label=colors_clusters[i])

leg = plt.legend(markerscale = 1, title = "Cluster", loc='upper right', bbox_to_anchor=(1.07, 1))

for lh in leg.legendHandles: 
    lh.set_alpha(1)

Equifax_X = CVE_Equifax["impact.baseMetricV3.exploitabilityScore"]
Equifax_Y = CVE_Equifax["impact.baseMetricV3.impactScore"]

plt.plot(Equifax_X, Equifax_Y, marker='x', markersize=10, color="black")
plt.annotate("CVE-2017-5638", color = "black", xy=(Equifax_X-.02, Equifax_Y-.02), xytext=(Equifax_X-.5, Equifax_Y-.5), arrowprops=dict(edgecolor="black", arrowstyle="->"))

plt.show();
